# %% [markdown]
# ##KELAPA SAWIT

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive

drive.mount('/content/drive')

df_1 = pd.read_csv('/content/drive/MyDrive/CesAlFem SIC/Kelapa Sawit/2016-2020.csv')
df_2 = pd.read_csv('/content/drive/MyDrive/CesAlFem SIC/Kelapa Sawit/2011-2015.csv')
df_3 = pd.read_csv('/content/drive/MyDrive/CesAlFem SIC/Kelapa Sawit/2006-2010.csv')
df_4 = pd.read_csv('/content/drive/MyDrive/CesAlFem SIC/Kelapa Sawit/2001-2005.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
li = []
li.append(df_1)
li.append(df_2)
li.append(df_3)
li.append(df_4)

frame = pd.concat(li, axis=0, ignore_index=True)

# %%
df_agg = frame.groupby(['Partner', 'Year']).agg({'Trade Value (US$)': 'sum'})

df_agg
# Out:
#                  Trade Value (US$)
# Partner    Year
# Bangladesh 2001           40052771
#            2002           77194355
#            2003           91147608
#            2004          102156914
#            2005          153577011
# ...                            ...
# USA        2016          458316149
#            2017          584970937
#            2018          550374948
#            2019          525865167
#            2020          609003096
#
# [100 rows x 1 columns]

# %%
ax = sns.lineplot(y='Trade Value (US$)', x='Year', hue='Partner', data=df_agg, palette='bright')
#ax.grid(True)
plt.xlabel('Tahun')
plt.ylabel('Nilai Ekspor')
plt.title('Ekspor Kelapa Sawit Indonesia 2001-2020')
plt.show()

# %% [markdown]
# ##KRUSTASEA

# %%
ks_1 = pd.read_csv('/content/drive/MyDrive/CesAlFem SIC/Krustasea/2016-2020.csv')

# %%
ks_agg = ks_1.groupby(['Partner', 'Year']).agg({'Trade Value (US$)': 'sum'})

ks_agg
# Out:
#                      Trade Value (US$)
# Partner        Year
# China          2016           52106754
#                2017           47856088
#                2018           70619296
#                2019           95889725
#                2020          110790371
# Japan          2016          295053046
#                2017          307221689
#                2018          293518223
#                2019          275780940
#                2020          258647771
# Malaysia       2016           30815836
#                2017           22545910
#                2018           25871086
#                2019           26138555
#                2020           23085162
# USA            2016          919530384
#                2017         1145029560
#                2018         1030348983
#                2019          880379377
#                2020         1034868932
# United Kingdom 2016           24223537
#                2017           17565917
# ...

# %%
kx = sns.lineplot(y='Trade Value (US$)', x='Year', hue='Partner', data=ks_agg, palette='bright')
#ax.grid(True)
plt.xlabel('Tahun')
plt.ylabel('Nilai Ekspor')
plt.title('Ekspor Krustasea Indonesia 2016-2020')
plt.show()

# %% [markdown]
# ##KOPI

# %%
kp_1 = pd.read_csv('/content/drive/MyDrive/CesAlFem SIC/Kopi/comtrade (3).csv')

# %%
kp_agg = kp_1.groupby(['Partner', 'Year']).agg({'Trade Value (US$)': 'sum'})

kp_agg
# Out:
#                Trade Value (US$)
# Partner  Year
# Germany  2016           90188916
#          2017          104020674
#          2018           42831472
#          2019           44911246
#          2020           49596250
# Italy    2016           66403758
#          2017           79664908
#          2018           54024572
#          2019           60354655
#          2020           44277971
# Japan    2016           86510840
#          2017           82420441
#          2018           84374664
#          2019           68572243
#          2020           56049267
# Malaysia 2016           71432154
#          2017           86968228
#          2018           70888722
#          2019           62937083
#          2020           62838500
# USA      2016          269941302
#          2017          256466210
#          2018          253773465
#          2019          253872313
#          2020          202452242

# %%
kox = sns.lineplot(y='Trade Value (US$)', x='Year', hue='Partner', data=kp_agg, palette='bright')
#ax.grid(True)
plt.xlabel('Tahun')
plt.ylabel('Nilai Ekspor')
plt.title('Ekspor Krustasea Indonesia 2016-2020')
plt.show()
