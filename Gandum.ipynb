# %% [markdown]
# ## IMPOR GANDUM

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ###Mengimpor CSV file Comtrade untuk Data Impor Gandum
# ###tahun 2001-2020 ke bentuk Dataframe pandas

# %%
df_1 = pd.read_csv('/content/drive/MyDrive/CesAlFem SIC/Gandum/comtrade.csv')
df_2 = pd.read_csv('/content/drive/MyDrive/CesAlFem SIC/Gandum/comtrade (1).csv')
df_3 = pd.read_csv('/content/drive/MyDrive/CesAlFem SIC/Gandum/comtrade (2).csv')
df_4 = pd.read_csv('/content/drive/MyDrive/CesAlFem SIC/Gandum/comtrade (3).csv')

# %% [markdown]
# ###Menggabungkan, mengurutkan, dan menampilkan Dataframe dari
# ###Data Impor tahun 2001-2020

# %%
df_all = df_1.append([df_2, df_3, df_4], ignore_index=True).sort_values(by='Year',
                                                     ascending=True,
                                                     kind='quicksort')

df_all[['Year', 'Trade Flow', 'Reporter', 'Partner', 'Trade Value (US$)']]
# Out:
#     Year Trade Flow   Reporter Partner  Trade Value (US$)
# 0   2001     Import  Indonesia   World          399521747
# 1   2002     Import  Indonesia   World          614447972
# 2   2003     Import  Indonesia   World          579924997
# 3   2004     Import  Indonesia   World          838577117
# 4   2005     Import  Indonesia   World          799003390
# 6   2006     Import  Indonesia   World          816120633
# 7   2007     Import  Indonesia   World         1181312663
# 8   2008     Import  Indonesia   World         1975480400
# 9   2009     Import  Indonesia   World         1316112428
# 5   2010     Import  Indonesia   World         1424275381
# 14  2011     Import  Indonesia   World         2193986487
# 10  2012     Import  Indonesia   World         2253850180
# 11  2013     Import  Indonesia   World         2439986682
# 12  2014     Import  Indonesia   World         2387262158
# 13  2015     Import  Indonesia   World         2082767824
# ...

# %% [markdown]
# ###Menampilkan visualisasi dari Dataframe menggunakan Lineplot

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(15,8))
ax = fig.add_subplot(111)

df_all['Year'] = df_all['Year'].astype('string')

sns.lineplot(data=df_all, x='Year', y='Trade Value (US$)', lw=4, label='Gandum', color='#4848FF',ax=ax)

plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1),fancybox=False, shadow=True, ncol=5,fontsize=12)
plt.grid(False)
plt.savefig('Impor Gandum Indonesia 2001-2020', transparent=True)

ax = plt.gca()

plt.yscale('linear')

plt.show()
